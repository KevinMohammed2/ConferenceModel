# %%
# ML Model for the CFB Game Predictor
import pandas as pd

# %%
team1 = pd.read_csv("UCF.csv")
team2 = pd.read_csv("Florida.csv")

# %%
team1
# Out:
#         Team Name  Team Points  Rushing TDs  Punt Return Yards  Punt Returns  \
# 0             UCF           35            2                 -3             1
# 1             TCU           34            0                 33             3
# 2             UCF           13            1                  0             0
# 3         Florida           24            2                  0             0
# 4   Arizona State           35            0                 46             1
# 5             UCF           31            4                  0             0
# 6         Arizona           12            0                  0             0
# 7             UCF           56            5                  0             0
# 8             UCF           57            5                107             8
# 9   New Hampshire            3            0                  0             0
# 10            UCF           21            1                 25             2
# ...

# %%
team2
# Out:
#             Team Name  Team Points  Rushing TDs  Punt Return Yards  \
# 0               Miami           41            2                  7
# 1             Florida           17            2                 28
# 2             Florida           48            5                  0
# 3            Kentucky           20            1                  7
# 4             Georgia           34            2                 21
# 5             Florida           20            1                 -1
# 6   Mississippi State           28            3                  0
# 7             Florida           45            3                 35
# 8                 UCF           13            1                  0
# 9             Florida           24            2                  0
# 10            Florida           20            1                  0
# 11          Texas A&M           33            1                  0
# 12            Florida           17            0                 57
# ...

# %%
team1.corr(numeric_only=True)["Team Points"]
# Out:
# Team Points               1.000000
# Rushing TDs               0.752414
# Punt Return Yards         0.545316
# Punt Returns              0.507649
# Passing TDs               0.388325
# Kick Return Yards        -0.348928
# Kick Returns             -0.480516
# Kicking Points            0.663271
# Tackles For Loss          0.340362
# Defensive TDs             0.228230
# Tackles                  -0.266798
# Sacks                     0.114898
# QB Hurries                0.483958
# Passes Deflected          0.201552
# Interceptions            -0.297086
# Turnovers                -0.325723
# Yards Per Rush Attempt    0.706849
# Rushing Attempts          0.482358
# Rushing Yards             0.711766
# Yards Per Pass            0.410432
# Net Passing Yards         0.233551
# Total Yards               0.830700
# Fourth Down Effects            NaN
# Third Down Effects             NaN
# First Downs               0.775855
# Name: Team Points, dtype: float64

# %%
import seaborn as sns

# %%
sns.lmplot(x="Rushing TDs", y="Team Points", data=team1, fit_reg=True, ci=None)

# %%
sns.lmplot(x="Passing TDs", y="Team Points", data=team1, fit_reg=True, ci=None)
